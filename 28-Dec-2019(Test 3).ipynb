# %%
import pandas as pd

# %%
train_data=pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %% [markdown]
# ##  1)Find the count of missing values in train dataset(train.csv)?

# %%
train_data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
test_data
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# ## 2)Combine both the test and train datasets.

# %%
merge_data = pd.merge(train_data,test_data,on='Self_Employed')
merge_data
# Out:
#        Loan_ID_x Gender_x Married_x Dependents_x   Education_x Self_Employed  \
# 0       LP001002     Male        No            0      Graduate            No
# 1       LP001002     Male        No            0      Graduate            No
# 2       LP001002     Male        No            0      Graduate            No
# 3       LP001002     Male        No            0      Graduate            No
# 4       LP001002     Male        No            0      Graduate            No
# ...          ...      ...       ...          ...           ...           ...
# 157265  LP002950     Male       Yes            0  Not Graduate           NaN
# 157266  LP002950     Male       Yes            0  Not Graduate           NaN
# 157267  LP002950     Male       Yes            0  Not Graduate           NaN
# 157268  LP002950     Male       Yes            0  Not Graduate           NaN
# 157269  LP002950     Male       Yes            0  Not Graduate           NaN
#
# ...

# %% [markdown]
# ## 3.Convert Gender,Married,Dependents,Education,Self_Employed,Property_Area into numeric form depending on column?

# %%
m3 = merge_data
m3
m3['Gender_x'].replace('Male',0,inplace=True)
m3['Gender_x'].replace('FeMale',1,inplace=True)
m3['Married_x'].replace('No',0,inplace=True)
m3['Married_x'].replace('Yes',1,inplace=True)
m3['Dependents_x'].replace('3+',3,inplace=True)
m3['Education_x'].replace('Graduate',1,inplace=True)
m3['Education_x'].replace('Not Graduate',0,inplace=True)
m3['Self_Employed'].replace('No',0,inplace=True)
m3['Self_Employed'].replace('Yes',1,inplace=True)
m3['Property_Area_y'].replace('Urban',1,inplace=True)
m3['Property_Area_y'].replace('Semi Urban',2,inplace=True)
m3['Property_Area_y'].replace('Rural',3,inplace=True)

# %%
m3
# Out:
#        Loan_ID_x Gender_x  Married_x Dependents_x  Education_x  Self_Employed  \
# 0       LP001002        0        0.0            0            1            0.0
# 1       LP001002        0        0.0            0            1            0.0
# 2       LP001002        0        0.0            0            1            0.0
# 3       LP001002        0        0.0            0            1            0.0
# 4       LP001002        0        0.0            0            1            0.0
# ...          ...      ...        ...          ...          ...            ...
# 157265  LP002950        0        1.0            0            0            NaN
# 157266  LP002950        0        1.0            0            0            NaN
# 157267  LP002950        0        1.0            0            0            NaN
# 157268  LP002950        0        1.0            0            0            NaN
# 157269  LP002950        0        1.0            0            0            NaN
#
# ...

# %% [markdown]
# ## 4)Also show the count for each column mentioned above after converting into numeric form?

# %%
Data1 = ['Gender']
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
